# %% [markdown]
# # All-in-one how to install and use JWST Pandeia Engine!
#
# ### Step 1) Create a virtual environment and install useful packages

# %% [raw]
# python3 -m venv .pandeia
# source .pandeia/bin/activate
# pip install pandeia.engine
# pip install ipykernel
# pip install matplotlib

# %% [markdown]
# ### Step 2) Install the required reference data!
# ### [Download from this link](https://outerspace.stsci.edu/spaces/PEN/pages/77530136/Pandeia+Engine+Installation)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step3) How to configure Pandeia!

# %%
# Pandeia reference data
import os
os.environ["pandeia_refdata"] = "./ref_data/pandeia_data-2025.7-jwst"
os.environ["PYSYN_CDBS"] = "./ref_data/hlsp_reference-atlases_hst_multi_everything_multi_v16_sed/grp/redcat/trds"

# Exposure time calculator
from pandeia.engine.calc_utils import build_default_calc
from pandeia.engine.perform_calculation import perform_calculation

# %% [markdown]
# ## If the functions imported successfully, you've correctly installed Pandeia Engine!
